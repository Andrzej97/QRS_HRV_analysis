# %%
# %matplotlib notebook

# %%
from multiprocessing.dummy import freeze_support
import wfdb
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# %%
freeze_support()
# download_all_files()
record = wfdb.rdrecord('db/100', sampto=3000)

# %%
print(record.p_signal)
print(len(record.p_signal))
wfdb.plot_items(signal=record.p_signal, title='MITDB Record 100')
# Out:
# [[-0.145 -0.065]
#  [-0.145 -0.065]
#  [-0.145 -0.065]
#  ...
#  [ 0.875  0.555]
#  [ 0.925  0.21 ]
#  [ 0.795 -0.125]]
# 3000
# <img src="data:image/png;base64,..." width="640">
# C:\ProgramData\Anaconda3\lib\site-packages\wfdb\plot\plot.py:120: MatplotlibDeprecationWarning: Passing arguments to show(), other than passing 'block' by keyword, is deprecated 3.1, and support for it will be removed in 3.3.
#   plt.show(fig)

# %%
signal_ch0 = list(map(lambda x: x[0], record.p_signal))
signal_ch0
# Out:
# [-0.145,
#  -0.145,
#  -0.145,
#  -0.145,
#  -0.145,
#  -0.145,
#  -0.145,
#  -0.145,
#  -0.12,
#  -0.135,
#  -0.145,
#  -0.15,
#  -0.16,
#  -0.155,
#  -0.16,
#  -0.175,
#  -0.18,
#  -0.185,
#  -0.17,
#  -0.155,
#  -0.175,
#  -0.18,
#  -0.19,
#  -0.18,
#  -0.155,
#  -0.135,
#  -0.155,
#  -0.19,
#  -0.205,
#  -0.235,
#  -0.225,
#  -0.245,
#  -0.25,
#  -0.26,
#  -0.275,
#  -0.275,
#  -0.275,
#  -0.265,
#  -0.255,
#  -0.265,
#  -0.275,
#  -0.29,
#  -0.29,
#  -0.29,
#  -0.29,
#  -0.285,
#  -0.295,
#  -0.305,
#  -0.285,
#  -0.275,
#  -0.275,
#  -0.28,
#  -0.285,
#  -0.305,
#  -0.29,
#  -0.3,
#  -0.28,
#  -0.29,
#  -0.3,
#  -0.315,
#  -0.32,
#  -0.335,
#  -0.36,
#  -0.385,
#  -0.385,
#  -0.405,
#  -0.455,
#  -0.485,
#  -0.485,
#  -0.425,
#  -0.33,
#  -0.22,
#  -0.07,
#  0.12,
#  0.375,
#  0.62,
#  0.78,
#  0.84,
#  0.765,
#  0.52,
#  0.17,
#  -0.165,
#  -0.365,
#  -0.435,
#  -0.425,
#  -0.37,
#  -0.33,
#  -0.325,
#  -0.335,
#  -0.345,
#  -0.33,
#  -0.325,
#  -0.315,
#  -0.31,
#  -0.32,
# ...

# %%
plt.plot(signal_ch0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ecg = np.array(signal_ch0)
peaks, _ = find_peaks(ecg)
negPeaks, _ = find_peaks(-ecg)

# %%
peaksX = peaks
peaksY = list(map(lambda x: ecg[x], peaks))

negPeaksX = negPeaks
negPeaksY = list(map(lambda x: ecg[x], negPeaks))

plt.plot(ecg)
plt.plot(peaksX, peaksY, 'ro')
plt.plot(negPeaksX, negPeaksY, 'bo')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
