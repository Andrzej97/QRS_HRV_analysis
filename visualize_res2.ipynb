# %%
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
results = pd.read_json('result.json')

# %%
print(results.shape)
results.head()
# Out:
# (37, 7)
#    filename  annotation_count  weight  threshold  true_positive  \
# 0       233              2230    0.05        0.1           2228
# 1       102                99    0.05        0.1             99
# 2       121              1861    0.05        0.1           1848
# 3       221              2031    0.05        0.1           2027
# 4       220              1954    0.05        0.1           1954
#
#    false_positive  false_negative
# 0             840               2
# 1            2089               0
# 2              41              13
# 3             411               4
# 4              94               0

# %%
results_per_param = results.drop(columns=['filename']).groupby(['weight', 'threshold'])
results_per_param = results_per_param.sum().reset_index()
results_per_param['accuracy'] = results_per_param['true_positive']  / (results_per_param['true_positive'] + results_per_param['false_negative'] + results_per_param['false_positive']) 
results_per_param['precision'] = results_per_param['true_positive']  / (results_per_param['true_positive'] + results_per_param['false_positive'])
results_per_param['recall'] = results_per_param['true_positive']  / (results_per_param['true_positive'] + results_per_param['false_negative']) 
results_per_param['TP detection %'] = results_per_param['true_positive']  / results_per_param['annotation_count']
results_per_param['errors%'] = (results_per_param['false_positive'] + results_per_param['false_negative'])  / results_per_param['annotation_count']

weight_best_acc, threshold_best_acc, best_acc = results_per_param.sort_values('accuracy', ascending=False).iloc[0][['weight', 'threshold', 'accuracy']]

print(f'Best acc for weight: {weight_best_acc}, threshold: {threshold_best_acc} -> {best_acc}')
results_per_param
# Out:
# Best acc for weight: 0.05, threshold: 0.1 -> 0.8139983466519702
#    weight  threshold  annotation_count  true_positive  false_positive  \
# 0    0.05        0.1             71407          70896           15689
#
#    false_negative  accuracy  precision    recall  TP detection %   errors%
# 0             511  0.813998   0.818802  0.992844        0.992844  0.226869

# %% [markdown]
# ## Accuracy dla wszystkich taśm dla (weight, threshold)

# %%
table_1 = pd.pivot_table(results_per_param, values='accuracy', index=['weight'], columns=['threshold'])
table_1
# Out:
# threshold       0.1
# weight
# 0.05       0.813998

# %%
weight_best_acc2, threshold_best_acc2, least_errors2 = results_per_param.sort_values('errors%', ascending=True).iloc[0][['weight', 'threshold', 'errors%']]

print(f'Least errors acc for weight: {weight_best_acc2}, threshold: {threshold_best_acc2} -> {least_errors2}')
# Out:
# Least errors acc for weight: 0.05, threshold: 0.1 -> 0.22686851429131596

# %%
table_2 = pd.pivot_table(results_per_param, values='errors%', index=['weight'], columns=['threshold'])
table_2
# Out:
# threshold       0.1
# weight
# 0.05       0.226869

# %%
results['accuracy'] = results['true_positive']  / (results['true_positive'] + results['false_negative'] + results['false_positive']) 
results['precision'] = results['true_positive']  / (results['true_positive'] + results['false_positive'])
results['recall'] = results['true_positive']  / (results['true_positive'] + results['false_negative']) 
results['TP detection %'] = results['true_positive']  / results['annotation_count']

# %% [markdown]
# ## Najlepsze accuracy dla taśm

# %%
results.groupby(['filename']).max().reset_index()[['filename', 'accuracy']]
# Out:
#     filename  accuracy
# 0        100  0.984602
# 1        101  0.991996
# 2        102  0.045247
# 3        103  0.998561
# 4        105  0.961024
# 5        106  0.729905
# 6        112  0.998032
# 7        113  0.995546
# 8        114  0.937403
# 9        115  0.998976
# 10       116  0.947826
# 11       117  0.995452
# 12       119  0.776157
# 13       121  0.971609
# 14       122  0.999193
# 15       123  0.998022
# 16       201  0.772484
# 17       202  0.935469
# 18       203  0.803870
# 19       205  0.972380
# 20       208  0.534442
# 21       209  0.872794
# 22       210  0.911631
# 23       212  0.335395
# 24       213  0.812808
# 25       215  0.949732
# 26       217  0.110658
# 27       219  0.959815
# 28       220  0.954102
# 29       221  0.830057
# 30       222  0.810076
# 31       223  0.819136
# 32       228  0.684458
# 33       230  0.998671
# 34       231  0.102495
# 35       233  0.725733
# 36       234  0.981461

# %% [markdown]
# ## całkowite accuracy

# %%
results
# Out:
#     filename  annotation_count  weight  threshold  true_positive  \
# 0        233              2230    0.05        0.1           2228
# 1        102                99    0.05        0.1             99
# 2        121              1861    0.05        0.1           1848
# 3        221              2031    0.05        0.1           2027
# 4        220              1954    0.05        0.1           1954
# 5        215              3195    0.05        0.1           3193
# 6        228              1688    0.05        0.1           1603
# 7        105              2526    0.05        0.1           2515
# 8        117              1534    0.05        0.1           1532
# 9        223              2029    0.05        0.1           2029
# 10       123              1515    0.05        0.1           1514
# 11       230              2255    0.05        0.1           2255
# 12       114              1820    0.05        0.1           1812
# 13       222              2062    0.05        0.1           2026
# 14       205              2571    0.05        0.1           2570
# 15       234              2700    0.05        0.1           2700
# 16       231               314    0.05        0.1            189
# 17       115              1953    0.05        0.1           1952
# 18       202              2061    0.05        0.1           2044
# 19       213              2641    0.05        0.1           2640
# 20       112              2537    0.05        0.1           2536
# 21       101              1860    0.05        0.1           1859
# 22       106              1507    0.05        0.1           1462
# 23       210              2423    0.05        0.1           2414
# 24       217               244    0.05        0.1            244
# 25       119              1543    0.05        0.1           1543
# 26       209              2621    0.05        0.1           2621
# 27       201              1625    0.05        0.1           1589
# 28       219              2082    0.05        0.1           2078
# 29       212               923    0.05        0.1            922
# 30       208              1586    0.05        0.1           1575
# 31       103              2082    0.05        0.1           2082
# 32       203              2529    0.05        0.1           2451
# 33       116              2302    0.05        0.1           2289
# 34       122              2476    0.05        0.1           2475
# 35       100              2239    0.05        0.1           2238
# 36       113              1789    0.05        0.1           1788
#
#     false_positive  false_negative  accuracy  precision    recall  \
# 0              840               2  0.725733   0.726206  0.999103
# 1             2089               0  0.045247   0.045247  1.000000
# 2               41              13  0.971609   0.978295  0.993015
# 3              411               4  0.830057   0.831419  0.998031
# 4               94               0  0.954102   0.954102  1.000000
# 5              167               2  0.949732   0.950298  0.999374
# 6              654              85  0.684458   0.710235  0.949645
# 7               91              11  0.961024   0.965081  0.995645
# 8                5               2  0.995452   0.996747  0.998696
# 9              448               0  0.819136   0.819136  1.000000
# 10               2               1  0.998022   0.998681  0.999340
# 11               3               0  0.998671   0.998671  1.000000
# 12             113               8  0.937403   0.941299  0.995604
# 13             439              36  0.810076   0.821907  0.982541
# 14              72               1  0.972380   0.972748  0.999611
# 15              51               0  0.981461   0.981461  1.000000
# 16            1530             125  0.102495   0.109948  0.601911
# 17               1               1  0.998976   0.999488  0.999488
# 18             124              17  0.935469   0.942804  0.991752
# 19             607               1  0.812808   0.813058  0.999621
# 20               4               1  0.998032   0.998425  0.999606
# 21              14               1  0.991996   0.992525  0.999462
# 22             496              45  0.729905   0.746680  0.970139
# 23             225               9  0.911631   0.914740  0.996286
# 24            1961               0  0.110658   0.110658  1.000000
# 25             445               0  0.776157   0.776157  1.000000
# 26             382               0  0.872794   0.872794  1.000000
# 27             432              36  0.772484   0.786244  0.977846
# 28              83               4  0.959815   0.961592  0.998079
# 29            1826               1  0.335395   0.335517  0.998917
# 30            1361              11  0.534442   0.536444  0.993064
# 31               3               0  0.998561   0.998561  1.000000
# 32             520              78  0.803870   0.824975  0.969158
# 33             113              13  0.947826   0.952956  0.994353
# 34               1               1  0.999193   0.999596  0.999596
# 35              34               1  0.984602   0.985035  0.999553
# 36               7               1  0.995546   0.996100  0.999441
#
#     TP detection %
# 0         0.999103
# 1         1.000000
# 2         0.993015
# 3         0.998031
# 4         1.000000
# 5         0.999374
# 6         0.949645
# 7         0.995645
# 8         0.998696
# 9         1.000000
# 10        0.999340
# 11        1.000000
# 12        0.995604
# 13        0.982541
# 14        0.999611
# 15        1.000000
# 16        0.601911
# 17        0.999488
# 18        0.991752
# 19        0.999621
# 20        0.999606
# 21        0.999462
# 22        0.970139
# 23        0.996286
# 24        1.000000
# 25        1.000000
# 26        1.000000
# 27        0.977846
# 28        0.998079
# 29        0.998917
# 30        0.993064
# 31        1.000000
# 32        0.969158
# 33        0.994353
# 34        0.999596
# 35        0.999553
# 36        0.999441
