# %%
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
# results = pd.concat([pd.read_json('results/result_2.json'), pd.read_json('results/result_1.json')])
results = pd.read_json('result.json')

# %%
print(results.shape)
results.head()
# Out:
# (40, 7)
#    filename  annotation_count  weight  threshold  true_positive  \
# 0       200              1743    0.05        0.1           1723
# 1       103              2082    0.05        0.1           2082
# 2       121              1861    0.05        0.1           1848
# 3       208              1586    0.05        0.1           1575
# 4       223              2029    0.05        0.1           2029
#
#    false_positive  false_negative
# 0             920              20
# 1               3               0
# 2              41              13
# 3            1361              11
# 4             448               0

# %%
results_per_param = results.drop(columns=['filename']).groupby(['weight', 'threshold'])
results_per_param = results_per_param.sum().reset_index()
results_per_param['accuracy'] = results_per_param['true_positive']  / (results_per_param['true_positive'] + results_per_param['false_negative'] + results_per_param['false_positive']) 
results_per_param['precision'] = results_per_param['true_positive']  / (results_per_param['true_positive'] + results_per_param['false_positive'])
results_per_param['recall'] = results_per_param['true_positive']  / (results_per_param['true_positive'] + results_per_param['false_negative']) 
results_per_param['TP detection %'] = results_per_param['true_positive']  / results_per_param['annotation_count']

weight_best_acc, threshold_best_acc, best_acc = results_per_param.sort_values('accuracy', ascending=False).iloc[0][['weight', 'threshold', 'accuracy']]

print(f'Best acc for weight: {weight_best_acc}, threshold: {threshold_best_acc} -> {best_acc}')
# Out:
# Best acc for weight: 0.05, threshold: 0.1 -> 0.7831218274111675

# %% [markdown]
# ## Accuracy dla wszystkich taśm dla (weight, threshold)

# %%
table_1 = pd.pivot_table(results_per_param, values='accuracy', index=['weight'], columns=['threshold'])
table_1
# Out:
# threshold       0.1
# weight
# 0.05       0.783122

# %%
results['accuracy'] = results['true_positive']  / (results['true_positive'] + results['false_negative'] + results['false_positive']) 
results['precision'] = results['true_positive']  / (results['true_positive'] + results['false_positive'])
results['recall'] = results['true_positive']  / (results['true_positive'] + results['false_negative']) 
results['TP detection %'] = results['true_positive']  / results['annotation_count']

# %% [markdown]
# ## Najlepsze accuracy dla taśm

# %%
results.groupby(['filename']).max().reset_index()[['filename', 'accuracy']]
# Out:
#     filename  accuracy
# 0        100  0.984602
# 1        101  0.991996
# 2        102  0.045247
# 3        103  0.998561
# 4        105  0.961024
# 5        106  0.729905
# 6        107  0.000000
# 7        108  0.537509
# 8        112  0.998032
# 9        113  0.995546
# 10       114  0.937403
# 11       115  0.998976
# 12       116  0.947826
# 13       117  0.995452
# 14       119  0.776157
# 15       121  0.971609
# 16       122  0.999193
# 17       123  0.998022
# 18       200  0.647015
# 19       201  0.772484
# 20       202  0.935469
# 21       203  0.803870
# 22       205  0.972380
# 23       208  0.534442
# 24       209  0.872794
# 25       210  0.911631
# 26       212  0.335395
# 27       213  0.812808
# 28       215  0.949732
# 29       217  0.110658
# 30       219  0.959815
# 31       220  0.954102
# 32       221  0.830057
# 33       222  0.810076
# 34       223  0.819136
# 35       228  0.684458
# 36       230  0.998671
# 37       231  0.102495
# 38       233  0.725733
# 39       234  0.981461

# %% [markdown]
# ## całkowite accuracy

# %%
results
# Out:
#     filename  annotation_count  weight  threshold  true_positive  \
# 0        200              1743    0.05        0.1           1723
# 1        103              2082    0.05        0.1           2082
# 2        121              1861    0.05        0.1           1848
# 3        208              1586    0.05        0.1           1575
# 4        223              2029    0.05        0.1           2029
# 5        215              3195    0.05        0.1           3193
# 6        115              1953    0.05        0.1           1952
# 7        201              1625    0.05        0.1           1589
# 8        100              2239    0.05        0.1           2238
# 9        114              1820    0.05        0.1           1812
# 10       203              2529    0.05        0.1           2451
# 11       116              2302    0.05        0.1           2289
# 12       234              2700    0.05        0.1           2700
# 13       205              2571    0.05        0.1           2570
# 14       220              1954    0.05        0.1           1954
# 15       112              2537    0.05        0.1           2536
# 16       231               314    0.05        0.1            189
# 17       210              2423    0.05        0.1           2414
# 18       117              1534    0.05        0.1           1532
# 19       119              1543    0.05        0.1           1543
# 20       108              1739    0.05        0.1           1433
# 21       219              2082    0.05        0.1           2078
# 22       228              1688    0.05        0.1           1603
# 23       212               923    0.05        0.1            922
# 24       209              2621    0.05        0.1           2621
# 25       105              2526    0.05        0.1           2515
# 26       213              2641    0.05        0.1           2640
# 27       233              2230    0.05        0.1           2228
# 28       222              2062    0.05        0.1           2026
# 29       113              1789    0.05        0.1           1788
# 30       202              2061    0.05        0.1           2044
# 31       123              1515    0.05        0.1           1514
# 32       122              2476    0.05        0.1           2475
# 33       102                99    0.05        0.1             99
# 34       101              1860    0.05        0.1           1859
# 35       217               244    0.05        0.1            244
# 36       221              2031    0.05        0.1           2027
# 37       230              2255    0.05        0.1           2255
# 38       107                 0    0.05        0.1              0
# 39       106              1507    0.05        0.1           1462
#
#     false_positive  false_negative  accuracy  precision    recall  \
# 0              920              20  0.647015   0.651911  0.988526
# 1                3               0  0.998561   0.998561  1.000000
# 2               41              13  0.971609   0.978295  0.993015
# 3             1361              11  0.534442   0.536444  0.993064
# 4              448               0  0.819136   0.819136  1.000000
# 5              167               2  0.949732   0.950298  0.999374
# 6                1               1  0.998976   0.999488  0.999488
# 7              432              36  0.772484   0.786244  0.977846
# 8               34               1  0.984602   0.985035  0.999553
# 9              113               8  0.937403   0.941299  0.995604
# 10             520              78  0.803870   0.824975  0.969158
# 11             113              13  0.947826   0.952956  0.994353
# 12              51               0  0.981461   0.981461  1.000000
# 13              72               1  0.972380   0.972748  0.999611
# 14              94               0  0.954102   0.954102  1.000000
# 15               4               1  0.998032   0.998425  0.999606
# 16            1530             125  0.102495   0.109948  0.601911
# 17             225               9  0.911631   0.914740  0.996286
# 18               5               2  0.995452   0.996747  0.998696
# 19             445               0  0.776157   0.776157  1.000000
# 20             927             306  0.537509   0.607203  0.824037
# 21              83               4  0.959815   0.961592  0.998079
# 22             654              85  0.684458   0.710235  0.949645
# 23            1826               1  0.335395   0.335517  0.998917
# 24             382               0  0.872794   0.872794  1.000000
# 25              91              11  0.961024   0.965081  0.995645
# 26             607               1  0.812808   0.813058  0.999621
# 27             840               2  0.725733   0.726206  0.999103
# 28             439              36  0.810076   0.821907  0.982541
# 29               7               1  0.995546   0.996100  0.999441
# 30             124              17  0.935469   0.942804  0.991752
# 31               2               1  0.998022   0.998681  0.999340
# 32               1               1  0.999193   0.999596  0.999596
# 33            2089               0  0.045247   0.045247  1.000000
# 34              14               1  0.991996   0.992525  0.999462
# 35            1961               0  0.110658   0.110658  1.000000
# 36             411               4  0.830057   0.831419  0.998031
# 37               3               0  0.998671   0.998671  1.000000
# 38            2135               0  0.000000   0.000000       NaN
# 39             496              45  0.729905   0.746680  0.970139
#
#     TP detection %
# 0         0.988526
# 1         1.000000
# 2         0.993015
# 3         0.993064
# 4         1.000000
# 5         0.999374
# 6         0.999488
# 7         0.977846
# 8         0.999553
# 9         0.995604
# 10        0.969158
# 11        0.994353
# 12        1.000000
# 13        0.999611
# 14        1.000000
# 15        0.999606
# 16        0.601911
# 17        0.996286
# 18        0.998696
# 19        1.000000
# 20        0.824037
# 21        0.998079
# 22        0.949645
# 23        0.998917
# 24        1.000000
# 25        0.995645
# 26        0.999621
# 27        0.999103
# 28        0.982541
# 29        0.999441
# 30        0.991752
# 31        0.999340
# 32        0.999596
# 33        1.000000
# 34        0.999462
# 35        1.000000
# 36        0.998031
# 37        1.000000
# 38             NaN
# 39        0.970139
