# %%
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
# results = pd.concat([pd.read_json('results/result_2.json'), pd.read_json('results/result_1.json')])
results = pd.read_json('result.json')

# %%
print(results.shape)
results.head()
# Out:
# (48, 7)
#    filename  annotation_count  weight  threshold  true_positive  \
# 0       111              2124    0.05        0.1           2124
# 1       200              2599    0.05        0.1           2594
# 2       234              2703    0.05        0.1           2698
# 3       109              2530    0.05        0.1           2529
# 4       105              2567    0.05        0.1           2553
#
#    false_positive  false_negative
# 0               1               0
# 1               7               5
# 2              53               5
# 3               2               1
# 4              51              14

# %%
results_per_param = results.drop(columns=['filename']).groupby(['weight', 'threshold'])
results_per_param = results_per_param.sum().reset_index()
results_per_param['accuracy'] = results_per_param['true_positive']  / (results_per_param['true_positive'] + results_per_param['false_negative'] + results_per_param['false_positive']) 
results_per_param['precision'] = results_per_param['true_positive']  / (results_per_param['true_positive'] + results_per_param['false_positive'])
results_per_param['recall'] = results_per_param['true_positive']  / (results_per_param['true_positive'] + results_per_param['false_negative']) 
results_per_param['TP detection %'] = results_per_param['true_positive']  / results_per_param['annotation_count']

weight_best_acc, threshold_best_acc, best_acc = results_per_param.sort_values('accuracy', ascending=False).iloc[0][['weight', 'threshold', 'accuracy']]

print(f'Best acc for weight: {weight_best_acc}, threshold: {threshold_best_acc} -> {best_acc}')
# Out:
# Best acc for weight: 0.05, threshold: 0.1 -> 0.9729876574512591

# %% [markdown]
# ## Accuracy dla wszystkich taśm dla (weight, threshold)

# %%
table_1 = pd.pivot_table(results_per_param, values='accuracy', index=['weight'], columns=['threshold'])
table_1
# Out:
# threshold       0.1
# weight
# 0.05       0.972988

# %%
results['accuracy'] = results['true_positive']  / (results['true_positive'] + results['false_negative'] + results['false_positive']) 
results['precision'] = results['true_positive']  / (results['true_positive'] + results['false_positive'])
results['recall'] = results['true_positive']  / (results['true_positive'] + results['false_negative'])

# %% [markdown]
# ## Najlepsze accuracy dla taśm

# %%
results.groupby(['filename']).max().reset_index()[['filename', 'accuracy']]
# Out:
#     filename  accuracy
# 0        100  0.999560
# 1        101  0.996790
# 2        102  0.999543
# 3        103  0.999520
# 4        104  0.976497
# 5        105  0.975172
# 6        106  0.980315
# 7        107  0.999065
# 8        108  0.917204
# 9        109  0.998815
# 10       111  0.999529
# 11       112  0.999606
# 12       113  0.995546
# 13       114  0.981023
# 14       115  0.998976
# 15       116  0.991312
# 16       117  0.999349
# 17       118  1.000000
# 18       119  0.999497
# 19       121  0.998391
# 20       122  1.000000
# 21       123  0.998025
# 22       124  0.975309
# 23       200  0.995395
# 24       201  0.923853
# 25       202  0.990169
# 26       203  0.943578
# 27       205  0.994731
# 28       207  0.815645
# 29       208  0.866509
# 30       209  0.999002
# 31       210  0.972065
# 32       212  0.999272
# 33       213  0.886189
# 34       214  0.996908
# 35       215  0.998811
# 36       217  0.997738
# 37       219  0.997683
# 38       220  1.000000
# 39       221  0.994655
# 40       222  0.908249
# 41       223  0.986953
# 42       228  0.940654
# 43       230  1.000000
# 44       231  0.943758
# 45       232  0.826941
# 46       233  0.994804
# 47       234  0.978955

# %% [markdown]
# ## całkowite accuracy

# %%
results.sort_values('accuracy', ascending=False)
# Out:
#     filename  annotation_count  weight  threshold  true_positive  \
# 41       118              2278    0.05        0.1           2278
# 33       220              2048    0.05        0.1           2048
# 6        122              2476    0.05        0.1           2476
# 18       230              2256    0.05        0.1           2256
# 43       112              2539    0.05        0.1           2539
# 29       100              2273    0.05        0.1           2272
# 12       102              2187    0.05        0.1           2187
# 0        111              2124    0.05        0.1           2124
# 47       103              2084    0.05        0.1           2084
# 14       119              1987    0.05        0.1           1987
# 34       117              1535    0.05        0.1           1535
# 25       212              2748    0.05        0.1           2747
# 23       107              2137    0.05        0.1           2136
# 38       209              3005    0.05        0.1           3003
# 17       115              1953    0.05        0.1           1952
# 3        109              2530    0.05        0.1           2529
# 9        215              3362    0.05        0.1           3360
# 11       121              1863    0.05        0.1           1862
# 19       123              1518    0.05        0.1           1516
# 44       217              2208    0.05        0.1           2205
# 40       219              2153    0.05        0.1           2153
# 42       214              2259    0.05        0.1           2257
# 45       101              1863    0.05        0.1           1863
# 27       113              1789    0.05        0.1           1788
# 1        200              2599    0.05        0.1           2594
# 32       233              3068    0.05        0.1           3063
# 36       205              2645    0.05        0.1           2643
# 35       221              2427    0.05        0.1           2419
# 39       116              2412    0.05        0.1           2396
# 21       202              2116    0.05        0.1           2115
# 5        223              2574    0.05        0.1           2572
# 7        114              1873    0.05        0.1           1861
# 10       106              2027    0.05        0.1           1992
# 2        234              2703    0.05        0.1           2698
# 30       104              2211    0.05        0.1           2202
# 46       124              1580    0.05        0.1           1580
# 4        105              2567    0.05        0.1           2553
# 26       210              2617    0.05        0.1           2575
# 13       231              1571    0.05        0.1           1527
# 37       203              2973    0.05        0.1           2843
# 15       228              2053    0.05        0.1           2013
# 8        201              1853    0.05        0.1           1832
# 28       108              1760    0.05        0.1           1706
# 16       222              2270    0.05        0.1           2257
# 31       213              2886    0.05        0.1           2881
# 22       208              2578    0.05        0.1           2564
# 20       232              1779    0.05        0.1           1768
# 24       207              1644    0.05        0.1           1637
#
#     false_positive  false_negative  accuracy  precision    recall
# 41               0               0  1.000000   1.000000  1.000000
# 33               0               0  1.000000   1.000000  1.000000
# 6                0               0  1.000000   1.000000  1.000000
# 18               0               0  1.000000   1.000000  1.000000
# 43               1               0  0.999606   0.999606  1.000000
# 29               0               1  0.999560   1.000000  0.999560
# 12               1               0  0.999543   0.999543  1.000000
# 0                1               0  0.999529   0.999529  1.000000
# 47               1               0  0.999520   0.999520  1.000000
# 14               1               0  0.999497   0.999497  1.000000
# 34               1               0  0.999349   0.999349  1.000000
# 25               1               1  0.999272   0.999636  0.999636
# 23               1               1  0.999065   0.999532  0.999532
# 38               1               2  0.999002   0.999667  0.999334
# 17               1               1  0.998976   0.999488  0.999488
# 3                2               1  0.998815   0.999210  0.999605
# 9                2               2  0.998811   0.999405  0.999405
# 11               2               1  0.998391   0.998927  0.999463
# 19               1               2  0.998025   0.999341  0.998682
# 44               2               3  0.997738   0.999094  0.998641
# 40               5               0  0.997683   0.997683  1.000000
# 42               5               2  0.996908   0.997790  0.999115
# 45               6               0  0.996790   0.996790  1.000000
# 27               7               1  0.995546   0.996100  0.999441
# 1                7               5  0.995395   0.997309  0.998076
# 32              11               5  0.994804   0.996422  0.998370
# 36              12               2  0.994731   0.995480  0.999244
# 35               5               8  0.994655   0.997937  0.996704
# 39               5              16  0.991312   0.997918  0.993367
# 21              20               1  0.990169   0.990632  0.999527
# 5               32               2  0.986953   0.987711  0.999223
# 7               24              12  0.981023   0.987268  0.993593
# 10               5              35  0.980315   0.997496  0.982733
# 2               53               5  0.978955   0.980734  0.998150
# 30              44               9  0.976497   0.980410  0.995929
# 46              40               0  0.975309   0.975309  1.000000
# 4               51              14  0.975172   0.980415  0.994546
# 26              32              42  0.972065   0.987725  0.983951
# 13              47              44  0.943758   0.970140  0.971992
# 37              40             130  0.943578   0.986126  0.956273
# 15              87              40  0.940654   0.958571  0.980516
# 8              130              21  0.923853   0.933741  0.988667
# 28             100              54  0.917204   0.944629  0.969318
# 16             215              13  0.908249   0.913026  0.994273
# 31             365               5  0.886189   0.887554  0.998267
# 22             381              14  0.866509   0.870628  0.994569
# 20             359              11  0.826941   0.831218  0.993817
# 24             363               7  0.815645   0.818500  0.995742

# %%
results.sort_values('accuracy', ascending=False).drop(columns=['weight', 'threshold']).to_excel('adapt_thresholding.xlsx')
